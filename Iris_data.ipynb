# %% [markdown]
# <a href="https://colab.research.google.com/github/arshh6/EDA-python/blob/main/Iris_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline
#sns.set(color_codes=True)

# %%
df = pd.read_csv("/content/iris.data")
df.head(10)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa

# %%
df.tail(25)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 124  7.2  3.2  6.0  1.8  Iris-virginica
# 125  6.2  2.8  4.8  1.8  Iris-virginica
# 126  6.1  3.0  4.9  1.8  Iris-virginica
# 127  6.4  2.8  5.6  2.1  Iris-virginica
# 128  7.2  3.0  5.8  1.6  Iris-virginica
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# 130  7.9  3.8  6.4  2.0  Iris-virginica
# 131  6.4  2.8  5.6  2.2  Iris-virginica
# 132  6.3  2.8  5.1  1.5  Iris-virginica
# 133  6.1  2.6  5.6  1.4  Iris-virginica
# 134  7.7  3.0  6.1  2.3  Iris-virginica
# 135  6.3  3.4  5.6  2.4  Iris-virginica
# 136  6.4  3.1  5.5  1.8  Iris-virginica
# 137  6.0  3.0  4.8  1.8  Iris-virginica
# 138  6.9  3.1  5.4  2.1  Iris-virginica
# 139  6.7  3.1  5.6  2.4  Iris-virginica
# 140  6.9  3.1  5.1  2.3  Iris-virginica
# 141  5.8  2.7  5.1  1.9  Iris-virginica
# 142  6.8  3.2  5.9  2.3  Iris-virginica
# 143  6.7  3.3  5.7  2.5  Iris-virginica
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# ...

# %%
df.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
pd.unique(df['Iris-setosa'])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df = df.drop(['1.4'], axis=1)
df.head(5)
# Out:
#    5.1  3.5  0.2  Iris-setosa
# 0  4.9  3.0  0.2  Iris-setosa
# 1  4.7  3.2  0.2  Iris-setosa
# 2  4.6  3.1  0.2  Iris-setosa
# 3  5.0  3.6  0.2  Iris-setosa
# 4  5.4  3.9  0.4  Iris-setosa

# %%
df = df.rename(columns={"5.1": "5", "3.5": "4", "Iris-setosa": "iris"})
df.head(5)
# Out:
#      5    4  0.2         iris
# 0  4.9  3.0  0.2  Iris-setosa
# 1  4.7  3.2  0.2  Iris-setosa
# 2  4.6  3.1  0.2  Iris-setosa
# 3  5.0  3.6  0.2  Iris-setosa
# 4  5.4  3.9  0.4  Iris-setosa

# %%
df.shape
# Out:
# (149, 4)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (7, 4)

# %%
df.count()
# Out:
# 5       149
# 4       149
# 0.2     149
# iris    149
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#      5    4  0.2         iris
# 0  4.9  3.0  0.2  Iris-setosa
# 1  4.7  3.2  0.2  Iris-setosa
# 2  4.6  3.1  0.2  Iris-setosa
# 3  5.0  3.6  0.2  Iris-setosa
# 4  5.4  3.9  0.4  Iris-setosa

# %%
df.count()
# Out:
# 5       142
# 4       142
# 0.2     142
# iris    142
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# 5       0
# 4       0
# 0.2     0
# iris    0
# dtype: int64

# %%
sns.boxplot(x=df['4'])
# Out:
# <Axes: xlabel='4'>

# %%
sns.boxplot(x=df['5'])
# Out:
# <Axes: xlabel='5'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['5'])
# Out:
# <Axes: xlabel='5', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['5'], y=df['4'])
# Out:
# <Axes: xlabel='5', ylabel='4'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['5'],y=df['4'])
# Out:
# <Axes: xlabel='5', ylabel='4'>

# %%
plt.figure(figsize=(10,5))
c= df.corr(numeric_only=True)
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
